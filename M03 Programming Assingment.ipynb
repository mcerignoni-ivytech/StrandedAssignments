# %%
#7.4
things = ["mozzarella", "cinderella", "salmonella"]

# %%
#7.5
things[1] = things[1].capitalize()
print(things) #Yes, it changes the elements in the list - capitalizing the first letter of each word that included "Cinderella" which refers to a person.
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
#7.6
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
#7.7
things = [element for element in things if element != "salmonella"]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %%
#9.1
def good():
    return ['Harry', 'Ron', 'Hermione']

good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
#9.2
def get_odds():
    for number in range (1, 10, 2):
        yield number

count = 0
for value in get_odds():
    count += 1
    if count == 3:
        print(value)
        break
# Out:
# 5
